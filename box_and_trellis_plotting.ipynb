# %% [markdown]
# <a href="https://colab.research.google.com/github/Uluc/machine_learning/blob/main/box_and_trellis_plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn import datasets

# %%
raw_data = datasets.load_wine()

# %% [markdown]
# That looks good, we've confirmed that we have 178 samples (rows) and 13 features (columns). Now let's build a pandas DataFrame to hold our data so that we can make use of all of its snazzy features. Then we'll take a look at the first few entries.

# %%
features = pd.DataFrame(data=raw_data['data'],columns=raw_data['feature_names'])
data = features
data['target']=raw_data['target']

# %%
data.describe()
# Out:
#           alcohol  malic_acid  ...      proline      target
# count  178.000000  178.000000  ...   178.000000  178.000000
# mean    13.000618    2.336348  ...   746.893258    0.938202
# std      0.811827    1.117146  ...   314.907474    0.775035
# min     11.030000    0.740000  ...   278.000000    0.000000
# 25%     12.362500    1.602500  ...   500.500000    0.000000
# 50%     13.050000    1.865000  ...   673.500000    1.000000
# 75%     13.677500    3.082500  ...   985.000000    2.000000
# max     14.830000    5.800000  ...  1680.000000    2.000000
#
# [8 rows x 14 columns]

# %%
g = sns.PairGrid(data, hue="target")
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend();

# %%
pearsoncorr =  data.groupby('target')[['alcohol','nonflavanoid_phenols']].corr(method='pearson')
pearsoncorr
# Out:
#                               alcohol  nonflavanoid_phenols
# target
# 0      alcohol               1.000000              0.015659
#        nonflavanoid_phenols  0.015659              1.000000
# 1      alcohol               1.000000             -0.068159
#        nonflavanoid_phenols -0.068159              1.000000
# 2      alcohol               1.000000              0.038158
#        nonflavanoid_phenols  0.038158              1.000000

# %%
pearsoncorr1 =  data.groupby('target')[['total_phenols','flavanoids']].corr(method='pearson')
pearsoncorr1
# Out:
#                       total_phenols  flavanoids
# target
# 0      total_phenols       1.000000    0.803784
#        flavanoids          0.803784    1.000000
# 1      total_phenols       1.000000    0.770999
#        flavanoids          0.770999    1.000000
# 2      total_phenols       1.000000    0.238915
#        flavanoids          0.238915    1.000000

# %%
data.boxplot(column=['proline'],by='target')
plt.title('proline')
plt.show()

# %%
data.boxplot(column=['alcohol'],by='target')
plt.title('alcohol')
plt.show()

# %%
data.boxplot(column=['malic_acid'],by='target')
plt.title('malic_acid')
plt.show()

# %%
data.boxplot(column=['ash'],by='target')
plt.title('ash')
plt.show()

# %%
data.boxplot(column=['alcalinity_of_ash'],by='target')
plt.title('alcalinity_of_ash')
plt.show()

# %%
data.boxplot(column=['magnesium'],by='target')
plt.title('magnesium')
plt.show()

# %%
data.boxplot(column=['total_phenols'],by='target')
plt.title('total_phenols')
plt.show()

# %%
data.boxplot(column=['flavanoids'],by='target')
plt.title('flavanoids')
plt.show()

# %%
data.boxplot(column=['nonflavanoid_phenols'],by='target')
plt.title('nonflavanoid_phenols')
plt.show()

# %%
data.boxplot(column=['proanthocyanins'],by='target')
plt.title('proanthocyanins')
plt.show()

# %%
data.boxplot(column=['color_intensity'],by='target')
plt.title('color_intensity')
plt.show()

# %%
data.boxplot(column=['od280/od315_of_diluted_wines'],by='target')
plt.title('od280/od315_of_diluted_wines')
plt.show()

# %%
data.boxplot(column=['hue'],by='target')
plt.title('hue')
plt.show()
